# %%
import lasio as ls
import pandas as pd
import missingno as ms
import seaborn as sns
import matplotlib.pyplot as plt
import welly as wl

# %%
df = ls.read('Barossa-2.las').df()
df.insert(0, 'DEPTH', df.index)
df.reset_index(drop=True, inplace=True)   
df
# Out:
#         DEPTH       TVD  ROP_AVG      TCDM  BITSIZE     GRCM  GRCFM  GR1BFM  \
# 0       338.0       NaN      NaN       NaN     17.5      NaN    NaN     NaN
# 1       338.1       NaN      NaN       NaN     17.5      NaN    NaN     NaN
# 2       338.2  338.1879   0.0000       NaN     17.5  59.2009    NaN     NaN
# 3       338.3  338.2879  22.7735       NaN     17.5  61.5788    NaN     NaN
# 4       338.4  338.3879  51.8717       NaN     17.5  63.9567    NaN     NaN
# ...       ...       ...      ...       ...      ...      ...    ...     ...
# 39626  4300.6       NaN      NaN  121.6621      8.5      NaN    NaN     NaN
# 39627  4300.7       NaN      NaN  121.6774      8.5      NaN    NaN     NaN
# 39628  4300.8       NaN      NaN       NaN      8.5      NaN    NaN     NaN
# 39629  4300.9       NaN      NaN       NaN      8.5      NaN    NaN     NaN
# 39630  4301.0       NaN      NaN       NaN      8.5      NaN    NaN     NaN
#
#        GR2BFM  GR1AFM  ...  CALCX  BDCX  DRHX  TCDX  GR2CX  ACTECDX  APRESX  \
# 0         NaN     NaN  ...    NaN   NaN   NaN   NaN    NaN      NaN     NaN
# 1         NaN     NaN  ...    NaN   NaN   NaN   NaN    NaN      NaN     NaN
# 2         NaN     NaN  ...    NaN   NaN   NaN   NaN    NaN      NaN     NaN
# 3         NaN     NaN  ...    NaN   NaN   NaN   NaN    NaN      NaN     NaN
# 4         NaN     NaN  ...    NaN   NaN   NaN   NaN    NaN      NaN     NaN
# ...       ...     ...  ...    ...   ...   ...   ...    ...      ...     ...
# 39626     NaN     NaN  ...    NaN   NaN   NaN   NaN    NaN      NaN     NaN
# 39627     NaN     NaN  ...    NaN   NaN   NaN   NaN    NaN      NaN     NaN
# 39628     NaN     NaN  ...    NaN   NaN   NaN   NaN    NaN      NaN     NaN
# 39629     NaN     NaN  ...    NaN   NaN   NaN   NaN    NaN      NaN     NaN
# 39630     NaN     NaN  ...    NaN   NaN   NaN   NaN    NaN      NaN     NaN
#
#        RACHX  RPCHX  NPLX
# 0        NaN    NaN   NaN
# 1        NaN    NaN   NaN
# 2        NaN    NaN   NaN
# 3        NaN    NaN   NaN
# 4        NaN    NaN   NaN
# ...      ...    ...   ...
# 39626    NaN    NaN   NaN
# 39627    NaN    NaN   NaN
# 39628    NaN    NaN   NaN
# 39629    NaN    NaN   NaN
# 39630    NaN    NaN   NaN
#
# [39631 rows x 36 columns]

# %%
df.DEPTH.max()
# Out:
# 4301.0

# %%
ms.matrix(df)
# Out:
# <AxesSubplot:>

# %%
sns.displot(
    data=df.isna().melt(value_name="missing"),
    y="variable",
    hue="missing",
    multiple="fill",
    aspect=2
);

# %%
wa=df.isna().melt(value_name="missing")
wa
# Out:
#         variable  missing
# 0          DEPTH    False
# 1          DEPTH    False
# 2          DEPTH    False
# 3          DEPTH    False
# 4          DEPTH    False
# ...          ...      ...
# 1426711     NPLX     True
# 1426712     NPLX     True
# 1426713     NPLX     True
# 1426714     NPLX     True
# 1426715     NPLX     True
#
# [1426716 rows x 2 columns]

# %%
sns.displot(
    data=df.isna().melt(value_name="missing"),
    y="variable",
    hue="missing",
    multiple="fill",
    aspect=2
);

# %%
from welly import Well

# %%
Well.from_las('Barossa-2.las').plot()
