# %%
import lasio
import welly

# %%
lasio_file_ver2 = lasio.read('./42303347740000.las')
lasio_file_ver2

# %%
lasio_file_ver2.df()
# Out:
#          CALI   DPHI     GR   NPHI     PE   RHOB   PHIX    C13    C24      DT  \
# DEPT
# 2587.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN  3.699  3.736  55.211
# 2587.5    NaN    NaN    NaN    NaN    NaN    NaN    NaN  3.702  3.737  55.473
# 2588.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN  3.693  3.739  55.467
# 2588.5    NaN    NaN    NaN    NaN    NaN    NaN    NaN  3.699  3.740  55.661
# 2589.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN  3.697  3.732  55.800
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...     ...
# 9108.0  4.688  0.004  22.33  0.018  5.622  2.703  0.017  7.890  7.938  49.300
# 9108.5  4.688  0.004  22.33  0.018  5.622  2.703  0.017  7.890  7.938  49.300
# 9109.0  4.688  0.004  22.33  0.018  5.622  2.703  0.017  7.890  7.938  49.300
# 9109.5  4.688  0.004  22.33  0.018  5.622  2.703  0.017    NaN    NaN     NaN
# 9110.0  4.688  0.004  22.33  0.018  5.622  2.703  0.017    NaN    NaN     NaN
#
# ...

# %%
welly_file_lasver2=welly.read_las('./42303347740000.las')
welly_file_lasver2.df()
# Out:
# 0it [00:00, ?it/s]
# 1it [00:00,  2.44it/s]
#                         CALI   DPHI     GR   NPHI     PE   RHOB   PHIX    C13  \
# UWI            DEPT
# 42303347740000 2587.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN  3.699
#                2587.5    NaN    NaN    NaN    NaN    NaN    NaN    NaN  3.702
#                2588.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN  3.693
#                2588.5    NaN    NaN    NaN    NaN    NaN    NaN    NaN  3.699
#                2589.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN  3.697
# ...                      ...    ...    ...    ...    ...    ...    ...    ...
#                9108.0  4.688  0.004  22.33  0.018  5.622  2.703  0.017  7.890
#                9108.5  4.688  0.004  22.33  0.018  5.622  2.703  0.017  7.890
#                9109.0  4.688  0.004  22.33  0.018  5.622  2.703  0.017  7.890
#                9109.5  4.688  0.004  22.33  0.018  5.622  2.703  0.017    NaN
# ...

# %% [markdown]
# ### Importing LAS 3.0 from Welly Dataset - Cutting Data

# %%
las30 = welly.read_las('./P-135_cuttings.las')
las30
# Out:
# /Users/ariewijaya/miniconda3/envs/streamlit/lib/python3.10/site-packages/welly/las.py:144: UserWarning: Warning, LAS version 3.0 not yet supported. Attempting to use LAS 1.2 and 2.0 parsing logic for LAS 3.0.
#   datasets = from_lasio(las)
# /Users/ariewijaya/miniconda3/envs/streamlit/lib/python3.10/site-packages/welly/las.py:169: UserWarning: Section was not recognized and not parsed: Lithology_Parameter
#   datasets = from_las_2_or_older(las)
# /Users/ariewijaya/miniconda3/envs/streamlit/lib/python3.10/site-packages/welly/las.py:169: UserWarning: Section was not recognized and not parsed: Lithology_Definition
#   datasets = from_las_2_or_older(las)
# 1it [00:00, 50.52it/s]
# Project(1 wells: )

# %% [markdown]
# ### Importing LAS 3.0 from Welly Dataset - Well Log Curves Data

# %%
welly.read_las('./Wellington_KGS-1-32-wDST2_LASv3.las')
# Out:
# /Users/ariewijaya/miniconda3/envs/streamlit/lib/python3.10/site-packages/lasio/las.py:284: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   arr[arr == provisional_null] = np.nan
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/envs/streamlit/lib/python3.10/site-packages/lasio/las.py:318, in LASFile.read(self, file_ref, ignore_data, read_policy, null_policy, ignore_header_errors, ignore_comments, mnemonic_case, index_unit, remove_data_line_filter, **kwargs)
#     317 try:
# --> 318     data = np.reshape(arr, (-1, n_columns_in_arr))
#     319 except ValueError as exception:
#
# File <__array_function__ internals>:180, in reshape(*args, **kwargs)
#
# File ~/miniconda3/envs/streamlit/lib/python3.10/site-packages/numpy/core/fromnumeric.py:298, in reshape(a, newshape, order)
# ...
